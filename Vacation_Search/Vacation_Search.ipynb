# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Albany      US  42.6001  -73.9662     26.17        53
# 1        1     Nolinsk      RU  57.5596   49.9363      1.71       100
# 2        2      Hobart      AU -42.8794  147.3294     60.66        82
# 3        3  Mahibadhoo      MV   3.7833   72.9667     81.48        78
# 4        4     Ushuaia      AR -54.8000  -68.3000     40.66        81
#
#    Cloudiness  Wind Speed Current Description             Date
# 0         100        1.99     overcast clouds  2/13/2022 19:47
# 1          95        3.31          light snow  2/13/2022 19:52
# 2          75       12.66       broken clouds  2/13/2022 19:45
# 3         100       12.06     overcast clouds  2/13/2022 19:52
# 4         100       26.46       moderate rain  2/13/2022 19:43

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria
min_temp = input("Please enter the minimum temperature criteria: ")
min_criteria = float(min_temp)
min_criteria = min_criteria
max_temp = input("Please enter the maximum temperature criteria: ")
max_criteria = float(max_temp)
max_criteria = max_criteria
# Out:
# Please enter the minimum temperature criteria: 75
# Please enter the maximum temperature criteria: 78

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
filtered_data_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_criteria) & (city_data_df["Max Temp"] <= max_criteria)]
filtered_data_df
# Out:
#      City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 9          9      Carnarvon      AU -24.8667  113.6333     77.07        88
# 16        16    San Quintin      MX  30.4833 -115.9500     76.03        20
# 33        33           Hilo      US  19.7297 -155.0900     76.24        77
# 52        52       Luderitz     NaN -26.6481   15.1594     75.22        62
# 61        61         Atuona      PF  -9.8000 -139.0333     77.54        79
# 83        83  Marsh Harbour      BS  26.5412  -77.0636     75.51        80
# 86        86          Reyes      BO -14.3167  -67.3833     76.96        83
# 97        97         Padang      ID  -0.9492  100.3543     76.50        84
# 110      110          Kapaa      US  22.0752 -159.3190     76.12        75
# 122      122   Vila Do Maio      CV  15.1333  -23.2167     75.99        75
# 130      130         Nabire      ID  -3.3667  135.4833     75.54        92
# ...

# %%
# 4a. Determine if there are any empty rows.
filtered_data_df.count()
# Out:
# City_ID                53
# City                   53
# Country                51
# Lat                    53
# Lng                    53
# Max Temp               53
# Humidity               53
# Cloudiness             53
# Wind Speed             53
# Current Description    53
# Date                   53
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = filtered_data_df.dropna(how='any')
clean_df.head()
# Out:
#     City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 9         9      Carnarvon      AU -24.8667  113.6333     77.07        88
# 16       16    San Quintin      MX  30.4833 -115.9500     76.03        20
# 33       33           Hilo      US  19.7297 -155.0900     76.24        77
# 61       61         Atuona      PF  -9.8000 -139.0333     77.54        79
# 83       83  Marsh Harbour      BS  26.5412  -77.0636     75.51        80
#
#     Cloudiness  Wind Speed Current Description             Date
# 9            3        5.75           clear sky  2/13/2022 19:48
# 16           9        7.52           clear sky  2/13/2022 19:49
# 33           0        3.44           clear sky  2/13/2022 19:47
# 61          24       14.74          light rain  2/13/2022 19:48
# 83         100       19.28          light rain  2/13/2022 19:53

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    print(row['City'])
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotel_name = requests.get(base_url, params=params)
    hotel_name = hotel_name.json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Carnarvon
# San Quintin
# Hilo
# Atuona
# Marsh Harbour
# Reyes
# Missing field/result... skipping.
# Padang
# Kapaa
# Vila Do Maio
# Nabire
# Rafai
# Missing field/result... skipping.
# Poso
# Mackay
# Richards Bay
# Vanimo
# Praia
# Praya
# Meulaboh
# Sao Filipe
# Amahai
# Muncar
# Paka
# Cam Ranh
# Sai Buri
# Bandarbeyla
# Salalah
# Namibe
# Labuhan
# Manggar
# Kalmunai
# Kupang
# Biankouma
# Road Town
# Beloha
# Missing field/result... skipping.
# Palu
# Sri Aman
# Eyl
# Kokopo
# Ambon
# Nacala
# Bengkulu
# Waingapu
# Makokou
# Mogadishu
# Jawhar
# Sao Domingos
# Yumbe
# Tarakan
# Makakilo City
# Tebingtinggi
# Camana

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[hotel_df["Hotel Name"] != ""].dropna(how='any')
clean_hotel_df
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 9        Carnarvon      AU     77.07           clear sky -24.8667  113.6333
# 16     San Quintin      MX     76.03           clear sky  30.4833 -115.9500
# 33            Hilo      US     76.24           clear sky  19.7297 -155.0900
# 61          Atuona      PF     77.54          light rain  -9.8000 -139.0333
# 83   Marsh Harbour      BS     75.51          light rain  26.5412  -77.0636
# 97          Padang      ID     76.50     overcast clouds  -0.9492  100.3543
# 110          Kapaa      US     76.12    scattered clouds  22.0752 -159.3190
# 122   Vila Do Maio      CV     75.99     overcast clouds  15.1333  -23.2167
# 130         Nabire      ID     75.54     overcast clouds  -3.3667  135.4833
# 181           Poso      ID     76.14     overcast clouds  -1.3959  120.7524
# 194         Mackay      AU     75.69       broken clouds -21.1500  149.2000
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 30.0), zoom_level=2.0)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# 11b. Display the figure
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
